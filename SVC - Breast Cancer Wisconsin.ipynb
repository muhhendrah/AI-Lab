# %% [markdown]
# # SVC - BREAST CANCER WISCONSIN

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set_style('darkgrid')

# %% [markdown]
# ## Load Data

# %%
df = pd.read_csv('breast_cancer.csv')

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.shape
# Out:
# (569, 33)

# %%
df.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
#drop unnamed column

df = df.iloc[:,1:-1]
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
df.isnull().sum()
# Out:
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %%
df.shape
# Out:
# (569, 31)

# %%
df.columns
# Out:
# Index(['diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
df.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %% [markdown]
# ## Data Preprocessing

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['diagnosis'] = le.fit_transform(df['diagnosis'])

df.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %% [markdown]
# ## Data Visualization

# %%
vars = df.iloc[:, 1:11]
vars
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
sns.pairplot(df, hue='diagnosis', vars = vars)

# %%
sns.countplot(df['diagnosis'], label='Count')
# Out:
# C:\Users\Awan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='diagnosis', ylabel='count'>

# %%
corr = df.corr()

# %%
plt.figure(figsize=(20,15))
sns.heatmap(corr, annot=True)
# Out:
# <AxesSubplot:>

# %%
corr.shape
# Out:
# (31, 31)

# %%
#Selecting Features

col = np.full((corr.shape[0],), True, dtype=bool)
for i in range(corr.shape[0]):
    for j in range(i+1, corr.shape[0]):
        if corr.iloc[i,j] >= 0.9:
            if col[j]:
                col[j] = False
new_columns = df.columns[col]
df = df[new_columns]

# %%
df.shape
# Out:
# (569, 21)

# %%
df.head()
# Out:
#    diagnosis  radius_mean  texture_mean  smoothness_mean  compactness_mean  \
# 0          1        17.99         10.38          0.11840           0.27760
# 1          1        20.57         17.77          0.08474           0.07864
# 2          1        19.69         21.25          0.10960           0.15990
# 3          1        11.42         20.38          0.14250           0.28390
# 4          1        20.29         14.34          0.10030           0.13280
#
#    concavity_mean  symmetry_mean  fractal_dimension_mean  radius_se  \
# 0          0.3001         0.2419                 0.07871     1.0950
# 1          0.0869         0.1812                 0.05667     0.5435
# 2          0.1974         0.2069                 0.05999     0.7456
# 3          0.2414         0.2597                 0.09744     0.4956
# 4          0.1980         0.1809                 0.05883     0.7572
#
#    texture_se  ...  compactness_se  concavity_se  concave points_se  \
# ...

# %% [markdown]
# ## Data Modeling

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

X = df.iloc[:, 1:21]
y = df.iloc[:, 0]

print('X shape:', X.shape)
print('y shape:', y.shape)
# Out:
# X shape: (569, 20)
# y shape: (569,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=15)

# %%
sc=StandardScaler()

X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.svm import SVC

# %% [markdown]
# ### SVC Linear Kernel

# %%
linear_model = SVC(kernel='linear')
linear_model.fit(X_train, y_train)
y_train_pred = linear_model.predict(X_train)
y_test_pred = linear_model.predict(X_test)

print('SVC LINEAR KERNEL TRAINING RESULT:')
print('======================================================')
print('Accuracy:', linear_model.score(X_train, y_train))
print('======================================================')
print('Classification Report --------------------------------')
print(classification_report(y_train, y_train_pred))
print('======================================================')
print('Confussion Matrix ------------------------------------')
print(confusion_matrix(y_train, y_train_pred))

print('\n======================================================')

print('\n SVC LINEAR KERNEL TESTING RESULT:')
print('======================================================')
print('Accuracy:', linear_model.score(X_test, y_test))
print('======================================================')
print('Classification Report --------------------------------')
print(classification_report(y_test, y_test_pred))
print('======================================================')
print('Confussion Matrix ------------------------------------')
print(confusion_matrix(y_test, y_test_pred))
# Out:
# SVC LINEAR KERNEL TRAINING RESULT:
# ...
# Accuracy: 0.989010989010989
# ...
# Classification Report --------------------------------
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       282
#            1       1.00      0.97      0.99       173
#
#     accuracy                           0.99       455
#    macro avg       0.99      0.99      0.99       455
# weighted avg       0.99      0.99      0.99       455
#
# ...
# Confussion Matrix ------------------------------------
# [[282   0]
#  [  5 168]]
#
# ...
#
#  SVC LINEAR KERNEL TESTING RESULT:
# ...
# Accuracy: 0.9298245614035088
# ...
# Classification Report --------------------------------
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.95        75
#            1       0.94      0.85      0.89        39
#
#     accuracy                           0.93       114
#    macro avg       0.93      0.91      0.92       114
# ...

# %% [markdown]
# ### SVC RBF Kernel

# %%
rbf_model = SVC(kernel='rbf')
rbf_model.fit(X_train, y_train)
y2_train_pred = rbf_model.predict(X_train)
y2_test_pred = rbf_model.predict(X_test)

print('SVC RBF KERNEL TRAINING RESULT:')
print('======================================================')
print('Accuracy:', rbf_model.score(X_train, y_train))
print('======================================================')
print('Classification Report --------------------------------')
print(classification_report(y_train, y2_train_pred))
print('======================================================')
print('Confussion Matrix ------------------------------------')
print(confusion_matrix(y_train, y2_train_pred))

print('\n======================================================')

print('\n SVC RBF KERNEL TESTING RESULT:')
print('======================================================')
print('Accuracy:', rbf_model.score(X_test, y_test))
print('======================================================')
print('Classification Report --------------------------------')
print(classification_report(y_test, y2_test_pred))
print('======================================================')
print('Confussion Matrix ------------------------------------')
print(confusion_matrix(y_test, y2_test_pred))
# Out:
# SVC RBF KERNEL TRAINING RESULT:
# ...
# Accuracy: 0.9868131868131869
# ...
# Classification Report --------------------------------
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       282
#            1       0.99      0.97      0.98       173
#
#     accuracy                           0.99       455
#    macro avg       0.99      0.98      0.99       455
# weighted avg       0.99      0.99      0.99       455
#
# ...
# Confussion Matrix ------------------------------------
# [[281   1]
#  [  5 168]]
#
# ...
#
#  SVC RBF KERNEL TESTING RESULT:
# ...
# Accuracy: 0.9649122807017544
# ...
# Classification Report --------------------------------
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97        75
#            1       1.00      0.90      0.95        39
#
#     accuracy                           0.96       114
#    macro avg       0.97      0.95      0.96       114
# ...

# %% [markdown]
# ### SVC Polynomial Kernel

# %%
poly_model = SVC(kernel='poly')
poly_model.fit(X_train, y_train)
y3_train_pred = poly_model.predict(X_train)
y3_test_pred = poly_model.predict(X_test)

print('SVC POLYNOMIAL KERNEL TRAINING RESULT:')
print('======================================================')
print('Accuracy:', poly_model.score(X_train, y_train))
print('======================================================')
print('Classification Report --------------------------------')
print(classification_report(y_train, y3_train_pred))
print('======================================================')
print('Confussion Matrix ------------------------------------')
print(confusion_matrix(y_train, y3_train_pred))

print('\n======================================================')

print('\n SVC POLYNOMIAL KERNEL TESTING RESULT:')
print('======================================================')
print('Accuracy:', poly_model.score(X_test, y_test))
print('======================================================')
print('Classification Report --------------------------------')
print(classification_report(y_test, y3_test_pred))
print('======================================================')
print('Confussion Matrix ------------------------------------')
print(confusion_matrix(y_test, y3_test_pred))
# Out:
# SVC POLYNOMIAL KERNEL TRAINING RESULT:
# ...
# Accuracy: 0.9208791208791208
# ...
# Classification Report --------------------------------
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94       282
#            1       1.00      0.79      0.88       173
#
#     accuracy                           0.92       455
#    macro avg       0.94      0.90      0.91       455
# weighted avg       0.93      0.92      0.92       455
#
# ...
# Confussion Matrix ------------------------------------
# [[282   0]
#  [ 36 137]]
#
# ...
#
#  SVC POLYNOMIAL KERNEL TESTING RESULT:
# ...
# Accuracy: 0.8859649122807017
# ...
# Classification Report --------------------------------
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92        75
#            1       1.00      0.67      0.80        39
#
#     accuracy                           0.89       114
#    macro avg       0.93      0.83      0.86       114
# ...
